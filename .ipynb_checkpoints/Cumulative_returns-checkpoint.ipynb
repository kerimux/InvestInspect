# %%
import pandas as pd
import yfinance as yf
import numpy as np

# %%
portfolio = {}

while True:
    stock = input("Enter a stock symbol (or 'done' to finish): ").upper()
    if stock == 'DONE':
        break
    quantity = int(input(f"Enter the quantity of {stock}: "))
    portfolio[stock] = quantity
    
    historical_data = {}
for stock_symbol in portfolio.keys():
    stock_data = yf.download(stock_symbol, period="5y")
    historical_data[stock_symbol] = stock_data['Close']
# Out:
# Enter a stock symbol (or 'done' to finish):  aapl
# Enter the quantity of AAPL:  10
# Enter a stock symbol (or 'done' to finish):  sbux
# Enter the quantity of SBUX:  10
# Enter a stock symbol (or 'done' to finish):  tsla
# Enter the quantity of TSLA:  10
# Enter a stock symbol (or 'done' to finish):  done
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
sp500_data = yf.download('^GSPC',period="5y")                        
sp500_closing_prices = sp500_data['Close']
sp500_closing_prices = pd.DataFrame(sp500_closing_prices)
sp500_closing_prices.columns = ['SP500']
sp500_returns = sp500_closing_prices.pct_change().dropna()
sp500_returns
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                SP500
# Date
# 2018-12-20 -0.015772
# 2018-12-21 -0.020588
# 2018-12-24 -0.027112
# 2018-12-26  0.049594
# 2018-12-27  0.008563
# ...              ...
# 2023-12-12  0.004599
# 2023-12-13  0.013651
# 2023-12-14  0.002647
# 2023-12-15 -0.000076
# 2023-12-18  0.004528
#
# [1257 rows x 1 columns]

# %%
historical_df = historical_df.reset_index().rename(columns={'index': 'Date'})
historical_df = pd.DataFrame(historical_data)
historical_df
# Out:
#                   AAPL       SBUX        TSLA
# Date
# 2018-12-19   40.222500  64.059998   22.198000
# 2018-12-20   39.207500  62.150002   21.025333
# 2018-12-21   37.682499  61.389999   21.318001
# 2018-12-24   36.707500  60.560001   19.692667
# 2018-12-26   39.292500  63.080002   21.739332
# ...                ...        ...         ...
# 2023-12-12  194.710007  98.150002  237.009995
# 2023-12-13  197.960007  98.110001  239.289993
# 2023-12-14  198.110001  97.839996  251.050003
# 2023-12-15  197.570007  96.750000  253.500000
# 2023-12-18  195.889999  96.559998  252.080002
#
# [1258 rows x 3 columns]

# %%
portfolio_returns = historical_df.pct_change().dropna()

portfolio_returns.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# Calculate cumulative returns of all portfolios


cumulative_returns = (1 + portfolio_returns).cumprod() - 1
cumulative_returns

# Plot cumulative returns
cumulative_returns.plot(title="Cumulative Returns of Apple, Tesla, and Starbucks Stocks" )
# Out:
# <Axes: title={'center': 'Cumulative Returns of Apple, Tesla, and Starbucks Stocks'}, xlabel='Date'>
